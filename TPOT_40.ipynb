# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix
from imblearn.over_sampling import SMOTE

import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
from tpot import TPOTClassifier


from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

df = pd.read_csv('data.csv')
list = ['Unnamed: 32','id']
df.drop(list,axis = 1, inplace = True)

#Encoding categorical data values
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df['diagnosis'] = labelencoder.fit_transform(df['diagnosis'])

from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
df['radius_mean'] = ss.fit_transform(df['radius_mean'].values.reshape(-1,1))
df['texture_mean'] = ss.fit_transform(df['texture_mean'].values.reshape(-1,1))
df['perimeter_mean'] = ss.fit_transform(df['perimeter_mean'].values.reshape(-1,1))
df['area_mean'] = ss.fit_transform(df['area_mean'].values.reshape(-1,1))
df['perimeter_se'] = ss.fit_transform(df['perimeter_se'].values.reshape(-1,1))
df['area_se'] = ss.fit_transform(df['area_se'].values.reshape(-1,1))
df['radius_worst'] = ss.fit_transform(df['radius_worst'].values.reshape(-1,1))
df['texture_worst'] = ss.fit_transform(df['texture_worst'].values.reshape(-1,1))
df['perimeter_worst'] = ss.fit_transform(df['perimeter_worst'].values.reshape(-1,1))
df['area_worst'] = ss.fit_transform(df['area_worst'].values.reshape(-1,1))

df_1 = pd.DataFrame(df['diagnosis'])
df.drop(['diagnosis'], axis =1, inplace = True)
df_2 = pd.DataFrame(df[['radius_mean', 'texture_mean', 'perimeter_mean', 
                        'smoothness_mean', 'area_mean', 'concavity_mean', 'compactness_mean', 
                        'texture_se', 'area_se', 'fractal_dimension_mean']])


from sklearn.decomposition import PCA
pca = PCA()
df_pca = pd.DataFrame(pca.fit_transform(df_2), columns=df_2.columns)



X = df_pca
Y = df_1['diagnosis']

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.20, 
                                                    stratify = Y)


sm = SMOTE(random_state=42, kind = 'borderline1')

X_resampled, Y_resampled = sm.fit_resample(X_train, Y_train)



tpot = TPOTClassifier(generations=40, population_size=20, verbosity=2)
tpot.fit(X_resampled, Y_resampled)
print(tpot.score(X_test, Y_test))
tpot.export('tpot_cancer_pipelinefinal3.py')
# Out:
# HBox(children=(IntProgress(value=0, description='Optimization Progress', max=820, style=ProgressStyle(descript…
# Generation 1 - Current best internal CV score: 0.9473684210526315
# Generation 2 - Current best internal CV score: 0.9473684210526315
# Generation 3 - Current best internal CV score: 0.9473684210526315
# Generation 4 - Current best internal CV score: 0.9526315789473685
# Generation 5 - Current best internal CV score: 0.9596491228070174
# Generation 6 - Current best internal CV score: 0.9596491228070174
# Generation 7 - Current best internal CV score: 0.9596491228070174
# Generation 8 - Current best internal CV score: 0.9596491228070174
# Generation 9 - Current best internal CV score: 0.9631578947368421
# Generation 10 - Current best internal CV score: 0.9719298245614036
# Generation 11 - Current best internal CV score: 0.9719298245614036
# Generation 12 - Current best internal CV score: 0.9719298245614036
# Generation 13 - Current best internal CV score: 0.9719298245614036
# Generation 14 - Current best internal CV score: 0.9719298245614036
# Generation 15 - Current best internal CV score: 0.9719298245614036
# Generation 16 - Current best internal CV score: 0.9719298245614036
# Generation 17 - Current best internal CV score: 0.9719298245614036
# Generation 18 - Current best internal CV score: 0.9719298245614036
# Generation 19 - Current best internal CV score: 0.9719298245614036
# Generation 20 - Current best internal CV score: 0.9719298245614036
# Generation 21 - Current best internal CV score: 0.9719298245614036
# Generation 22 - Current best internal CV score: 0.9719298245614036
# Generation 23 - Current best internal CV score: 0.9719298245614036
# Generation 24 - Current best internal CV score: 0.9719298245614036
# Generation 25 - Current best internal CV score: 0.9719298245614036
# Generation 26 - Current best internal CV score: 0.9719298245614036
# Generation 27 - Current best internal CV score: 0.9719298245614036
# Generation 28 - Current best internal CV score: 0.9719298245614036
# Generation 29 - Current best internal CV score: 0.9719298245614036
# Generation 30 - Current best internal CV score: 0.9719298245614036
# Generation 31 - Current best internal CV score: 0.9719298245614036
# Generation 32 - Current best internal CV score: 0.9719298245614036
# Generation 33 - Current best internal CV score: 0.9719298245614036
# Generation 34 - Current best internal CV score: 0.9719298245614036
# Generation 35 - Current best internal CV score: 0.9719298245614036
# Generation 36 - Current best internal CV score: 0.9719298245614036
# Generation 37 - Current best internal CV score: 0.9719298245614036
# Generation 38 - Current best internal CV score: 0.9719298245614036
# Generation 39 - Current best internal CV score: 0.9719298245614036
# Generation 40 - Current best internal CV score: 0.9719298245614036
#
# Best pipeline: LogisticRegression(StandardScaler(PolynomialFeatures(MinMaxScaler(input_matrix), degree=2, include_bias=False, interaction_only=False)), C=10.0, dual=True, penalty=l2)
# 0.9122807017543859
